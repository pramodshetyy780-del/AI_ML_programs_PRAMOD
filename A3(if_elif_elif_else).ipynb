# %%
print("Crop Yield Classification")
crop_yield=float(input("Enter the crop yield in quintals:"))
if crop_yield>=50:
    print("High Yield")
elif crop_yield<=49 and crop_yield>=30:
    print("Medium Yield")
elif crop_yield<30:
    print("low yield")
else:
  print("error")
# Out:
# Crop Yield Classification
