# %%
crop_name=str(input("Enter crop name: \t"))
soil_nitrogen=int(input("Enter soil nitrogen level:\t"))
if crop_name=="Rice" and soil_nitrogen<50:
  print("Apply Urea")
elif crop_name=="Wheat" and soil_nitrogen<40:
    print("Apply DAP")
else:
      print("Fertilizer not required")
