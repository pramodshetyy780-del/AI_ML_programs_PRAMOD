# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodshetyy780-del/AI_ML_programs_PRAMOD/blob/main/assignmentprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
r=[]
n=int(input("how many months rainfall you want to enter:"))
for i in range (n):
 rain=float(input(f"rainfall in month {i+1}:"))
 r.append(rain)
rainfall=np.array(r)
y=[]
for i in range(n):
  yield_val=float(input(f"yield in month{i+1}:"))
  y.append(yield_val)
yields=np.array(y)
# Out:
# how many months rainfall you want to enter:3
# rainfall in month 1:11
# rainfall in month 2:22
# rainfall in month 3:33
# yield in month1:44.4
# yield in month2:66
# yield in month3:77

# %%
import numpy as np
r=[]
n=int(input("how many months rainfall you want to enter:"))
for i in range (n):
 rain=float(input(f"rainfall in month {i+1}:"))
 r.append(rain)
rainfall=np.array(r)
y=[]
for i in range(n):
  yield_val=float(input(f"yield in month{i+1}:"))
  y.append(yield_val)
yields=np.array(y)
print('===rainfall statistics===')
print(f'mean:{np.mean(rainfall):.2f}mm')
print(f'median:{np.median(rainfall):.2f}mm')
print(f'std dev:{np.std(rainfall):.2f}mm')
print(f'variance:{np.var(rainfall):.2f}mm')
print(f'minimum:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'maximum:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
print(f'range:{np.ptp(rainfall)}mm')
print('\n===yield statistics===')
print(f"mean:{np.mean(yields):.2f}tons/ha")
print(f'median:{np.median(yields):.2f}tons/ha')
print(f'std dev:{np.std(yields):.2f}tons/ha')
print('\n===percentile===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:.2f}mm')
print('\n===correlation analysis===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'rainfall_yield correlation:{correlation:.4f}')
print(f'interpretation:strong positive correlation if correlation>0.7 else "moderate correlation' if correlation>0.4 else 'weak correlation')
print('\n===cumulative rainfall===')
cumulative=np.cumsum(rainfall)
print('month\trainfall\tcumulative')
for month,(rain,cum) in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# how many months rainfall you want to enter:12
# rainfall in month 1:45
# rainfall in month 2:52
# rainfall in month 3:68
# rainfall in month 4:120
# rainfall in month 5:180
# rainfall in month 6:220
# rainfall in month 7:195
# rainfall in month 8:160
# rainfall in month 9:110
# rainfall in month 10:75
# rainfall in month 11:58
# rainfall in month 12:40
# yield in month1:2.1
# yield in month2:2.3
# yield in month3:2.8
# yield in month4:4.2
# yield in month5:5.8
# yield in month6:6.5
# yield in month7:5.9
# yield in month8:5.2
# yield in month9:3.8
# yield in month10:2.9
# yield in month11:2.4
# yield in month12:2.0
# ===rainfall statistics===
# mean:110.25mm
# median:92.50mm
# std dev:61.24mm
# variance:3750.52mm
# minimum:40.0mm(month12)
# maximum:220.0mm(month6)
# range:180.0mm
#
# ===yield statistics===
# mean:3.82tons/ha
# median:3.35tons/ha
# std dev:1.58tons/ha
#
# ===percentile===
# 25th percentile rainfall:56.50mm
# 50th percentile rainfall:92.50mm
# 75th percentile rainfall:165.00mm
# 90th percentile rainfall:193.50mm
#
# ===correlation analysis===
# rainfall_yield correlation:0.9983
# interpretation:strong positive correlation if correlation>0.7 else "moderate correlation
#
# ===cumulative rainfall===
# month	rainfall	cumulative
# 1	45.0		45.0
# 2	52.0		97.0
# 3	68.0		165.0
# 4	120.0		285.0
# 5	180.0		465.0
# 6	220.0		685.0
# 7	195.0		880.0
# 8	160.0		1040.0
# 9	110.0		1150.0
# 10	75.0		1225.0
# 11	58.0		1283.0
# 12	40.0		1323.0
