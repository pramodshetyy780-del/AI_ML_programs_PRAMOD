# %%
enter_name=str(input("Enter your name: "))
enter_age=int(input("Enter your age: "))
enter_course=str(input("Enter your course: "))

# Initialize pg to None to prevent NameError later if 'bsc' path isn't taken
pg = None

if enter_course=='bscag':
  print("go to another course")
elif enter_course=='bsc':
  pg=str(input("planning to do Masters"))
else: # This 'else' now correctly aligns with the 'if' and 'elif'
  print("die")

# Check if pg was assigned 'Yes' before using it
if pg=='Yes':
  print("Please get married")
# Out:
# Enter your name: abhi
# Enter your age: 100
# Enter your course: mbbs
# die
# Please get married
