# %%
crop="paddy"
soil_type="black Soil"
print(len(crop))
print(len(soil_type))
# Out:
# 5
# 10

# %%
crop="groundnut"
print(crop[0])
print(crop[-1])
print(crop[:5])
print(crop[5:])
# Out:
# g
# t
# groun
# dnut

# %%
print("rice".upper())
print("wheat".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
crop="* *# # ricce * ***######"
print(crop.strip())
print(crop.lstrip())
print(crop.rstrip())
for _ in crop:
 print(crop.strip("*"))
# Out:
# * *# # ricce * ***######
# * *# # ricce * ***######
# * *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######
#  *# # ricce * ***######

# %%
text="organic rice and rice cultivation"
print(text.find("rice"))
print(text.count("rice"))
print("rice"in text)
# Out:
# 8
# 2
# True

# %%
print("ricE".isalpha())
print("2026.5".isdigit())
print("plot12#".isalnum())
print("".isspace())
# Out:
# True
# False
# False
# False

# %%
codes=[
    "CRP_Rice_2026",
    "CRP_Wheat_2025",
    "CRP_Cotton_2024",
    "CRP_Groundnut_2023"
]
clean_codes=[]
for code in codes:
  if code.startswith("CRP_"):
    clean_codes.append(code[4:])
print(clean_codes)
# Out:
# ['Rice_2026', 'Wheat_2025', 'Cotton_2024', 'Groundnut_2023']

# %%
for crop_code in codes:
  if crop_code.startswith("CRP_"):
    code,crop,year=crop_code.split("_")
    print(crop,year)
# Out:
# Rice 2026
# Wheat 2025
# Cotton 2024
# Groundnut 2023
