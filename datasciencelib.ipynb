# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodshetyy780-del/AI_ML_programs_PRAMOD/blob/main/datasciencelib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
mydataset={
    'cars':["BMW","volvo","ford"],
    'passings':[3,7,2]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  volvo         7
# 2   ford         2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["1x",2,"z"])
print(myvar)
print(myvar[2])
# Out:
# 1x    1
# 2     7
# z     2
# dtype: int64
# 7

# %%
import pandas as pd
a=[1,"x",2]
myvar=pd.Series(a,index=[100.12345,200,300])
print(myvar)
print(myvar[200])
# Out:
# 100.12345    1
# 200.00000    x
# 300.00000    2
# dtype: object
# x

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
for val in s:
   print(val)
print(s)
# Out:
# 10
# 20
# 30
# 40
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 0 10
# 1 20
# 2 30
# 3 40

# %%
for idx, val in s.items():
  print(idx,val)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %%
import pandas as pd
s=pd.Series([100,200,300],['a','b','c'])
print(s)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
for label,value in s.items():
  print(label,value)
# Out:
# a 100
# b 200
# c 300

# %%
for label in s.index:
  print(label)
# Out:
# a
# b
# c

# %%
for value in s.values:
  print(value)
# Out:
# 100
# 200
# 300

# %%
print(s.iloc[0])
print(s.['a'])
# Out:
#   File "/tmp/ipython-input-4237629796.py", line 2
#     print(s.['a'])
#             ^
# SyntaxError: invalid syntax
