# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.DataFrame({
    'name':['alice','bob','charlie','david','eva','frank'],
    'department':['hr','it','it','finance','hr','finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
},index=['employee1','employee2','employee3','employee4','employee5','employee6'])
print(df)
df[['salary','experience']].plot()
plt.show()
# Out:
#               name department  salary  experience
# employee1    alice         hr   50000           2
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee4    david    finance   60000           6
# employee5      eva         hr   52000           3
# employee6    frank    finance   60000           6

# %%
df.plot(kind='bar',x='name',y='salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['salary'].plot(kind='hist',bins=5)
plt.show()

# %%
df.plot(kind='scatter',x='experience',y='salary')
plt.show()

# %%
df[['salary','experience']].plot(kind='box')
plt.show()

# %%
df.loc['employee1']
# Out:
# name          alice
# department       hr
# salary        50000
# experience        2
# Name: employee1, dtype: object

# %%
df.loc['employee1','name']
# Out:
# 'alice'

# %%
df.loc[:,'name']
# Out:
# employee1      alice
# employee2        bob
# employee3    charlie
# employee4      david
# employee5        eva
# employee6      frank
# Name: name, dtype: object

# %%
df.loc['employee1':'employee5',['name','salary']]
# Out:
#               name  salary
# employee1    alice   50000
# employee2      bob   70000
# employee3  charlie   70000
# employee4    david   60000
# employee5      eva   52000

# %%
df[df['salary']>55000]
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee4    david    finance   60000           6
# employee6    frank    finance   60000           6

# %%
df[(df['salary']>50000)&(df['experience']>3)]
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee4    david    finance   60000           6
# employee6    frank    finance   60000           6

# %%
df[(df['experience']>2)|(df['salary']>65000)]
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee4    david    finance   60000           6
# employee5      eva         hr   52000           3
# employee6    frank    finance   60000           6

# %%
df[df['experience'].isin([3,4,5])]
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee5      eva         hr   52000           3

# %%
df[df['experience'].between(3,5)]
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee5      eva         hr   52000           3

# %%
df.query('salary>50000')
# Out:
#               name department  salary  experience
# employee2      bob         it   70000           5
# employee3  charlie         it   70000           4
# employee4    david    finance   60000           6
# employee5      eva         hr   52000           3
# employee6    frank    finance   60000           6

# %%
df.query('salary>50000 and experience>4')
# Out:
#             name department  salary  experience
# employee2    bob         it   70000           5
# employee4  david    finance   60000           6
# employee6  frank    finance   60000           6
