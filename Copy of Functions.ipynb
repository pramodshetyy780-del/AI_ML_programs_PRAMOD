# %%
#no argument passed
def crp_no():
  #assume values are fixed
  return 150
crp_no()
# Out:
# 150

# %%
#o arguement passed, no value returned
def wthr_upd():
   print("The weather today is sunny wih no rain")
wthr_upd()
# Out:
# The weather today is sunny wih no rain

# %%
#only one arguement,no value returned
#void function
def plant_info(plant_name):
    # Fixed: Use an f-string for proper formatting so {plant_name} is replaced.
    print(f"The {plant_name}, requires 8 hrs of sun-light")
plant_info("Snake plant")
# Out:
# The Snake plant, requires 8 hrs of sun-light

# %%
def plant_type(plant_type):
  if plant_type=="corn":
    return 30
  elif plant_type=="wheat":
      return 20
  else:
        return 25
water_needs("brinjal")
# Out:
# 25

# %%
#two arguments are passed,no value is returned
def irri_need(moisture_level,rain):
  if moisture_level<=40 and rain<=10:
    print("irrigation needed")
  else:
      print("irrigatipon not needed")
irri_need(40,10)
# Out:
# irrigation needed

# %%
#two arguments passed,value is returned
def total_yield(area,yield_per_hectare):
  return area*yield_per_hectare
total_yield(2,20)
# Out:
# 40

# %%
def total_yield():
  area=int(input("Enter the area \n"))
  yield_pha=int(input("Enter the yield per hectare \n"))
  cal_yld=area*yield_pha
  return cal_yld
y=total_yield()
print("\n total yield is ",y)
# Out:
# Enter the area
# 10
# Enter the yield per hectare
# 10
#
#  total yield is  100

# %%
def harvest_rdy(da_p, pt):
  if da_p >= 120 and pt == "Rice":
    return True
  else:
    return False

# Get input from the user before calling the function
da_p = int(input("Enter number of days after planting: "))
pt = input("Enter plant type: ")

# Call the function with the obtained inputs and print the result
print(harvest_rdy(da_p, pt))
# Out:
# Enter number of days after planting: 170
# Enter plant type: Rice
# True

# %%
#returning multiple values
def weather_conditions():
  temperature=28
  humidity=70
  return temperature,humidity

temp,hum=weather_conditions()
print(f"temperature:{temp}celsius,humidity:{hum}%")
# Out:
# temperature:28celsius,humidity:70%

# %%
def add(x,y):
    return x+y
def subtract(x,y):
    return x-y
def multiply(x,y):
    return x*y
def divide(x,y):
    return x/y
    if y==0:
      return "Error!! kindly avoid 0 as denominator"
    else:
      return x/y
def get_input():
  try:
     x=float(input("Enter the first number:"))
     y=float(input("Enter the second number:"))
     return x,y
  except:
    print("Invalid input!! Kindly use Integers and Decimals")
    return get_input()
def print_menu():
  print("\n Calculator Menu:")
  print("1. Addition")
  print("2. Subtraction")
  print("3. Multiplication")
  print("4. Division")
  print("5. Exit")
def calculator():
 while True:
  print_menu()
  choice=input("Enter your choice \n")
  if choice=='5':
    print("Exiting Calculator")
    break
  x,y=get_input()
  if choice=='1':
    print(f"{x}+{y}={add(x,y)}")
  elif choice=='2':
    print(f"{x}-{y}={subtract(x,y)}")
  elif choice=='3':
    print(f"{x}*{y}={multiply(x,y)}")
  elif choice=='4':
    print(f"{x}/{y}={divide(x,y)}")
  else:
    print("Invalid input!!Kindly use valid numbers")
calculator()
print("Done with Calculator")
# Out:
#  Calculator Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice
# 1
# Enter the first number:2
# Enter the second number:3
# 2.0+3.0=5.0
#
#  Calculator Menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice
# 5
# Exiting Calculator
# Done with Calculator
