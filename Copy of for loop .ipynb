# %%
crops=["Rice","Wheat","Maize"]
for crop in crops:
  print(crop)
# Out:
# Rice
# Wheat
# Maize

# %%
crops=["Rice","Wheat","Maize"]
crop="Rice""wheat""Maize"
for letter in crop:
  print(letter)
# Out:
# R
# i
# c
# e
# w
# h
# e
# a
# t
# M
# a
# i
# z
# e

# %%
days=int(input("enter number of days:"))#3
total_yield=0
for day in range (1,4):
  yield_today=float(input(f"Enter yield for day {day}:"))
  total_yield+=yield_today
  print("total yield", total_yield)
# Out:
# enter number of days:3
# Enter yield for day 1:400
# total yield 400.0
# Enter yield for day 2:600
# total yield 1000.0
# Enter yield for day 3:900
# total yield 1900.0
