# %%
x=20
y=15

print("x==y",x==y)
print("x!=y",x!=y)
print("x>y",x>y)
print("x<y",x<y)
print("x>=y",x>=y)
print("x<=y",x<=y)
# Out:
# x==y False
# x!=y True
# x>y True
# x<y False
# x>=y True
# x<=y False
