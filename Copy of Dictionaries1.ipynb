# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={"crop":"cotton","organic":True,"variety":"dch-32","year":2024,"irrigation_methods":["drip","sprinkler","flood"]}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'variety': 'dch-32', 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict=dict(farmername="ramesh",age=45,village="mandya")
print(thisdict)
# Out:
# {'farmername': 'ramesh', 'age': 45, 'village': 'mandya'}

# %%
x=thisdict["variety"]
print(x)
# Out:
# dch-32

# %%
x=thisdict.get("variety")
print(x)
# Out:
# dch-32

# %%
x=thisdict.keys()
print(x)
# Out:
# dict_keys(['crop', 'organic', 'variety', 'year', 'irrigation_methods'])

# %%
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
# Out:
# dict_keys(['crop', 'organic', 'variety', 'year', 'irrigation_methods', 'season'])
# dict_keys(['crop', 'organic', 'variety', 'year', 'irrigation_methods', 'season'])

# %%
farm={"crop":"cotton","organic":True,"variety":"dch-32","year":2024,"irrigation_methods":["drip","sprinkler","flood"]}
farm["year"]="2025"
print(farm)
# Out:
# {'crop': 'cotton', 'organic': True, 'variety': 'dch-32', 'year': '2025', 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={"crop":"cotton","organic":True,"variety":"dch-32","year":2024,"irrigation_methods":["drip","sprinkler","flood"]}
if "variety" in thisdict:
  print("yes,'variety' is one of the keys in the thisdict dictionary")
# Out:
# yes,'variety' is one of the keys in the thisdict dictionary

# %%
student={
    "name":"pramod",
    "roll_no":"amb2177",
    "branch":"bsc agri",
    "marks":90
}
print("original dictionary:",student)
student_copy=student.copy()
print("copied dictionary:",student_copy)

removed_value=student.pop("marks")
print("Removed Value:", removed_value)
print("After removing Marks:",student)

last_item=student.popitem()
print("removed item:",last_item)
print("after update():",student)
student.update({"year": 4, "branch": "AI & DS"})
print("After update():", student)
student.clear()
print("After clear():", student)
del student
# Out:
# original dictionary: {'name': 'pramod', 'roll_no': 'amb2177', 'branch': 'bsc agri', 'marks': 90}
# copied dictionary: {'name': 'pramod', 'roll_no': 'amb2177', 'branch': 'bsc agri', 'marks': 90}
# Removed Value: 90
# After removing Marks: {'name': 'pramod', 'roll_no': 'amb2177', 'branch': 'bsc agri'}
# removed item: ('branch', 'bsc agri')
# after update(): {'name': 'pramod', 'roll_no': 'amb2177'}
# After update(): {'name': 'pramod', 'roll_no': 'amb2177', 'year': 4, 'branch': 'AI & DS'}
# After clear(): {}
