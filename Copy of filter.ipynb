# %%
lst=[1,2,-3,4]
def filter_positive(lst):
  result=[]
  for num in lst:
    if num>0:
     result.append(num*2)
  return result
print(filter_positive(lst))
# Out:
# [2, 4, 8]

# %%
fields=[[10,0,15][0,20,0][5,10,25]]
irrigated=0
for row in range(len(fields))
