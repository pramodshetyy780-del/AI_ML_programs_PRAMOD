# %%
season=input("Enter season(kharif/rabi)").lower()
rainfall=int(input("enter rainfall in mm:"))
if season=="Kharif":
  if rainfall >600:
    print("Grow rice")
  else:
    print("Grow Pulses")
else:
    print("Grow wheat")
# Out:
# Enter season(kharif/rabi)Kharif
# enter rainfall in mm:800
# Grow wheat
