# %%
  rainfall=float(input("Enter rainfall in mm"))
  if  rainfall <500:
    print("suitable crop:Millets")
  elif rainfall <1000:
      print("suitable crop:Rice")
  else:
          print("suitable crop:Sugarcane")
# Out:
# Enter rainfall in mm999.99
# suitable crop:Rice
