# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodshetyy780-del/AI_ML_programs_PRAMOD/blob/main/pandasdataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'name':['alice','bob','charlie','david','eva','frank'],
    'department':['hr','it','it','finance','hr','finance'],
    'salary':[50000,70000,70000,60000,52000,60000],
    'experience':[2,5,4,6,3,6]
})
print(df)
# Out:
#       name department  salary  experience
# 0    alice         hr   50000           2
# 1      bob         it   70000           5
# 2  charlie         it   70000           4
# 3    david    finance   60000           6
# 4      eva         hr   52000           3
# 5    frank    finance   60000           6

# %%
sal=df.sort_values('salary')
print(sal)
# Out:
#       name department  salary  experience
# 0    alice         hr   50000           2
# 4      eva         hr   52000           3
# 5    frank    finance   60000           6
# 3    david    finance   60000           6
# 2  charlie         it   70000           4
# 1      bob         it   70000           5

# %%
sal=df.sort_values('salary',ascending=False)
print(sal)
sal=df.sort_values(['salary','experience'],ascending=[False,True])
print(sal)
# Out:
#       name department  salary  experience
# 1      bob         it   70000           5
# 2  charlie         it   70000           4
# 5    frank    finance   60000           6
# 3    david    finance   60000           6
# 4      eva         hr   52000           3
# 0    alice         hr   50000           2
#       name department  salary  experience
# 2  charlie         it   70000           4
# 1      bob         it   70000           5
# 3    david    finance   60000           6
# 5    frank    finance   60000           6
# 4      eva         hr   52000           3
# 0    alice         hr   50000           2

# %%
sal=df.sort_values(['salary','experience'])
print(sal)
# Out:
#       name department  salary  experience
# 0    alice         hr   50000           2
# 4      eva         hr   52000           3
# 3    david    finance   60000           6
# 5    frank    finance   60000           6
# 2  charlie         it   70000           4
# 1      bob         it   70000           5

# %%
des=df.sort_index(ascending=False)
print(des)
# Out:
#       name department  salary  experience
# 5    frank    finance   60000           6
# 4      eva         hr   52000           3
# 3    david    finance   60000           6
# 2  charlie         it   70000           4
# 1      bob         it   70000           5
# 0    alice         hr   50000           2

# %%
#basic ranking
df['rank_salary']=df['salary'].rank()
print(df)
# Out:
#       name department  salary  experience  rank_salary
# 0    alice         hr   50000           2          1.0
# 1      bob         it   70000           5          5.5
# 2  charlie         it   70000           4          5.5
# 3    david    finance   60000           6          3.5
# 4      eva         hr   52000           3          2.0
# 5    frank    finance   60000           6          3.5

# %%
df['denserank_salary']=df['rank_salary'].rank(ascending=False,method='dense')
print(df)
# Out:
#       name department  salary  experience  rank_salary  denserank_salary
# 0    alice         hr   50000           2          1.0               4.0
# 1      bob         it   70000           5          5.5               1.0
# 2  charlie         it   70000           4          5.5               1.0
# 3    david    finance   60000           6          3.5               2.0
# 4      eva         hr   52000           3          2.0               3.0
# 5    frank    finance   60000           6          3.5               2.0

# %%
df=df['department'].value_counts()
print(df)
# Out:
# department
# hr         2
# it         2
# finance    2
# Name: count, dtype: int64

# %%
df=df['department'].value_counts(normalize=True)
print(df)
# Out:
# department
# hr         0.333333
# it         0.333333
# finance    0.333333
# Name: proportion, dtype: float64
