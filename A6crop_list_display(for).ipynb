# %% [markdown]
# Lab Assignment 6: Crop List Display
# Create a list containing the following crops:
# Rice, Wheat, Maize, Millet
# Display each crop name using a loop.

# %%
crops=["Rice","Wheat","Maize","Millets"]
for crop in crops:
  print(crop)
# Out:
# Rice
# Wheat
# Maize
# Millets
