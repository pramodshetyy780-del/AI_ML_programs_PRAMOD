# %%
print("CROP ANALYSIS")
crop_name = input("enter crop name:")
problem_noticed = input("enter problem noticed:")
if problem_noticed:
    print("Spray Wettable SULPHUR @ 8gm/ltr")
# Out:
# CROP ANALYSIS
# enter crop name:grapes
# enter problem noticed:Pwdery mildew
# Spray Wettable SULPHUR @ 8gm/ltr
