# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodshetyy780-del/AI_ML_programs_PRAMOD/blob/main/mathML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def predicted_yield(rain,fertilizer,base=1000):
  rain_coeff=10
  fert_coeff=15
  predicted=base+(rain*rain_coeff)+(fertilizer*fert_coeff)
  return predicted
print("===this is a linear model===")
print(f"100mm rain, 50 units fert:{predict_yield(100,50)}kg/ha")
def profit_function(fertilizer_amount,price_per_kg=20,fert_cost_per_unit=50):
  yield_increase=500*math.sqrt(fertilizer_amount)
  revenue=yield_increase*price_per_kg
  cost=fertilizer_amount*fert_cost_per_unit
  profit=revenue-cost
  return profit
print("===optimization:best fertilizer amount===")
for fert in
