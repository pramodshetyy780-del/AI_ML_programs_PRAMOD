# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodshetyy780-del/AI_ML_programs_PRAMOD/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
crops=['rice','wheat','maize']
yeild_per_acre=[20,30,40]
area=10
c=np.array(crops)
ypa=np.array(yeild_per_acre)
for crop,single_yield in zip(c,ypa):
   tot_yield=single_yield*area
   print(f" {crop} total yeild = {tot_yield} quintals")
# Out:
#  rice total yeild = 200 quintals
#  wheat total yeild = 300 quintals
#  maize total yeild = 400 quintals

# %%
import numpy as np
rainfall=[120,80,100,150,200,90]
r=np.array(rainfall)
print(f'highest rainfall = {np.max(r)}mm')
print(f'lowest rainfall ={np.min(r)}mm')
print(f'mean rainfall ={np.mean(r)}mm')
# Out:
# highest rainfall = 200mm
# lowest rainfall =80mm
# mean rainfall =123.33333333333333mm

# %%
crop_price={"wheat":2400,
            "rice":3000,
            "maize":2100}
k=crop_price.keys()
v=crop_price.values()
for crop,price in zip(k,v):
  print(crop,':',price)
for crop,price in zip(k,v):
  if price==max(v):
   print(f'highest priced crop = {crop}')
# Out:
# wheat : 2400
# rice : 3000
# maize : 2100
# highest priced crop = rice

# %%
yield_val=200
price=25
cost=4000
profit=(yield_val*price)-cost
if profit<0:
  print("loss")
elif profit==0:
  print("zero profit but no loss")
else :
  print(f"it is a profit and profit={profit}")
# Out:
# it is a profit and profit=1000

# %%
import numpy as np
crops=['rice','wheat','maize']
yeild_per_acre=[20,30,40]
area=10
c=np.array(crops)
ypa=np.array(yeild_per_acre)
for crop,single_yield in zip(c,ypa):
   tot_yield=single_yield*area
   print(f" {crop} total yeild = {tot_yield} quintals")
import numpy as np
rainfall=[120,80,100,150,200,90]
r=np.array(rainfall)
print(f'highest rainfall = {np.max(r)}mm')
print(f'lowest rainfall ={np.min(r)}mm')
print(f'mean rainfall ={np.mean(r)}mm')
crop_price={"wheat":2400,
            "rice":3000,
            "maize":2100}
k=crop_price.keys()
v=crop_price.values()
for crop,price in zip(k,v):
  print(crop,':',price)
for crop,price in zip(k,v):
  if price==max(v):
   print(f'highest priced crop = {crop}')
yield_val=200
price=25
cost=4000
profit=(yield_val*price)-cost
if profit<0:
  print("loss")
elif profit==0:
  print("zero profit but no loss")
else :
  print(f"it is a profit and profit={profit}")
# Out:
#  rice total yeild = 200 quintals
#  wheat total yeild = 300 quintals
#  maize total yeild = 400 quintals
# highest rainfall = 200mm
# lowest rainfall =80mm
# mean rainfall =123.33333333333333mm
# wheat : 2400
# rice : 3000
# maize : 2100
# highest priced crop = rice
# it is a profit and profit=1000
