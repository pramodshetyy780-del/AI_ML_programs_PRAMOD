# %%
a=4
print("Initial value:",a)

a+=5
print("After +=:",a)

a-=3
print("After -=:",a)

a*=2
print("After *=:",a)

a/=4
print("After /=:",a)

a//=2
print("After //=:",a)

a%=5
print("After %=:",a)

a**=2
print("After **=:",a)
# Out:
# Initial value: 4
# After +=: 9
# After -=: 6
# After *=: 12
# After /=: 3.0
# After //=: 1.0
# After %=: 1.0
# After **=: 1.0
