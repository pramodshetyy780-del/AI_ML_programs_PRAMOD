# %%
list=[1,2,3,4,5]
list.copy()
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
list1=["watermelon","kiwi","dates"]
list2=[1,2,3,4]
list3=[True,False,False]
list1.append(list3)
list1.append(list2)
print("Modified list:",list1)
# Out:
# Modified list: ['watermelon', 'kiwi', 'dates', [True, False, False], [1, 2, 3, 4]]

# %%
list=
